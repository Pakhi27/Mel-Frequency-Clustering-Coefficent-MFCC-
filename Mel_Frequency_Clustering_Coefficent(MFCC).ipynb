# %% [markdown]
# <a href="https://colab.research.google.com/github/Pakhi27/Mel-Frequency-Clustering-Coefficent-MFCC-/blob/main/Mel_Frequency_Clustering_Coefficent(MFCC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Loading audio files with Librosa

# %%
audio_file = "/content/drive/MyDrive/BabyElephantWalk60.wav"

# %%
ipd.Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# load audio files with librosa
signal, sr = librosa.load(audio_file)

# %%
signal.shape
# Out:
# (1323000,)

# %% [markdown]
# Extracting MFCCs

# %%
mfccs = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=sr)
# mel frequency cepstral coefficent
# 13 initial number if mfcc's

# %%
mfccs.shape
# Out:
# (13, 2584)

# %% [markdown]
# Visualising MFCCs

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(mfccs,
                         x_axis="time",
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.show()

# %% [markdown]
# Computing first / second MFCCs derivatives

# %%
delta_mfccs = librosa.feature.delta(mfccs)

# %%
delta2_mfccs = librosa.feature.delta(mfccs, order=2)

# %%
delta_mfccs.shape
# Out:
# (13, 2584)

# %%
mfccs.shape
# Out:
# (13, 2584)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(delta_mfccs,
                         x_axis="time",
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.show()

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(delta2_mfccs,
                         x_axis="time",
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.show()

# %%
mfccs_features = np.concatenate((mfccs, delta_mfccs, delta2_mfccs))

# %%
mfccs_features.shape
# 39 mfcc's for each frame
# 13*3=399intial_1st derivative+2nd derivative
# Out:
# (39, 2584)
